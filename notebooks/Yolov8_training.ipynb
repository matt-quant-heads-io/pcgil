# %%
# !nvidia-smi

# %%
# !pip install -U ultralytics==8.0.20

from IPython import display

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 26.3/166.8 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !ls "/content/drive/MyDrive/Colab Notebooks"
# %cd "/content/drive/MyDrive/Colab Notebooks"

# %%
# !yolo task=segment mode=train model=yolov8x.pt data="/content/drive/MyDrive/Colab Notebooks/project-18-at-2024-01-25-22-06-b1f179ae/data.yaml" patience=500 epochs=500 imgsz=928 plots=False
